# %%
import numpy as np
import pandas as pd
import cv2 as cv
import matplotlib.pyplot as plt

img = cv.imread("test.jpg")

plt.imshow(img)
print(img.shape)

img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
plt.imshow(img_gray)
print(img_gray)
# Out:
# (225, 225, 3)
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
plt.grid("img")
plt.xlabel("X-Axis")
plt.ylabel("y-Axis")
plt.imshow(img)

# %%
img = cv.imread("test.jpg") 
scale_per = 75
plt.imshow(img)
width = int(img.shape[1]*scale_per/100)
height = int(img.shape[0]*scale_per/100)
img_resh = cv.resize(img,(width,height))
print("original img",img.shape)
print("new img",img_resh.shape)
# Out:
# original img (225, 225, 3)
# new img (168, 168, 3)

# %%
img = cv.imread("test.jpg") 
scale_per = 75
plt.imshow(img)
#width = int(img.shape[1]*scale_per/100)
height = int(img.shape[0]*scale_per/100)
img_resh = cv.resize(img,(img.shape[0],height))
print("original img",img.shape)
print("new img",img_resh.shape)
# Out:
# original img (225, 225, 3)
# new img (168, 225, 3)

# %%
img = cv.imread("test.jpg") 
plt.imshow(img)
print(img.shape)
img1 = img+50
print(img1.shape)
plt.imshow(img1)
# Out:
# (225, 225, 3)
# (225, 225, 3)

# %%
img = cv.imread("test.jpg") 
plt.imshow(img)
print(img.shape)
img1 = img-50
print(img1.shape)
plt.imshow(img1)
# Out:
# (225, 225, 3)
# (225, 225, 3)

# %%
img = cv.imread("test.jpg") 
plt.imshow(img)
print(img.shape)
img1 = img*90
print(img1.shape)
plt.imshow(img1)
# Out:
# (225, 225, 3)
# (225, 225, 3)

# %%
img = cv.imread("test.jpg") 
plt.imshow(img)
print(img.shape)
img1 = img/60
print(img1.shape)
plt.imshow(img1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (225, 225, 3)
# (225, 225, 3)

# %%
#subplot is a points in graph
img = cv.imread("test.jpg") 
plt.imshow(img)
print(img.shape)
#(+,
plt.subplot(141)
plt.imshow(img)
# (-,+)
plt.subplot(142)
plt.imshow(img[:,::-1])
#(+,-)
plt.subplot(143)
plt.imshow(img[::-1,:])
#(-,-)
plt.subplot(144)
plt.imshow(img[::-1,::-1])
# Out:
# (225, 225, 3)
# C:\Users\rocks\AppData\Local\Temp\ipykernel_11740\2159366523.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)

# %%
img = cv.imread("test.jpg") 
plt.imshow(img)
print(img.shape)
plt.subplot(221)
img_fh=cv.flip(img,0)
plt.imshow(img_fh)
plt.subplot(222)
img_fv=cv.flip(img,1)
plt.imshow(img_fv)
plt.subplot(223)
img_fhv=cv.flip(img,-1)
plt.imshow(img_fhv)
plt.subplot(224)
plt.imshow(img)
# Out:
# (225, 225, 3)
# C:\Users\rocks\AppData\Local\Temp\ipykernel_11740\1097783605.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(221)

# %%
import cv2 as cv
img= cv.imread("test.jpg")
plt.imshow(img)
img1= cv.imread("test2.jpg")
print(img.shape)
print(img1.shape)
plt.imshow(img1)
# Out:
# (225, 225, 3)
# (2000, 3000, 3)

# %%
img_resize = cv.resize(img1,(img.shape[0],img.shape[1]))
print(img_resize.shape)
# Out:
# (225, 225, 3)

# %%
result = cv.addWeighted(img1,0.4,img_resize,0.6,0.7)
plt.imshow(result)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 result = cv.addWeighted(img1,0.4,img_resize,0.6,0.7)
#       2 plt.imshow(result)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %% [markdown]
# # Equalized Code

# %%
# Assuming "image" is your original image in BGR format
# Convert BGR image to grayscale
plt.subplot(1,2,1)
plt.title("original")
plt.imshow(img)

img_gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

equalized_img = cv.equalizeHist(img_gray)

cv.imwrite('equalized.jpeg',equalized_img)
    
plt.subplot(1,2,2)
plt.title("equalized")
plt.imshow(equalized_img)

# %%
#remove noise form img
#shapness of img
#inverse of transform

# %% [markdown]
# # Edge Detection

# %%
# Edge Detection
import numpy as np
import pandas as pd
import cv2 as cv
import matplotlib.pyplot as plt
def main():
    img = cv.imread("test.jpg", 1)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    k1= np.array(([1, 0, -1], [0, 0, 0], [-1, 0, 1]), np.float32)
    k2= np.array(([0, -1, 0], [-1, 4, -1], [0, -1, 0]), np.float32) 
    k3= np.array(([-1, -1, -1], [-1, 8, -1], [-1, -1, -1]), np.float32)

    output1 = cv.filter2D(img, -1, k1)
    output2 = cv.filter2D(img, -1, k2)
    output3 = cv.filter2D(img, -1, k3)
    plt.subplot(2,2, 1)
    plt.imshow(img)

    plt.subplot(2, 2, 1)
    plt.imshow(img)

    plt.title('Original Image')
    plt.subplot(2, 2, 2)
    plt.imshow(output1)

    plt.title('Filtered Image-Edge Detection-k1')
    plt.subplot(2, 2, 3)
    plt.imshow(output2)

    plt.title('Filtered Image-Edge Detection-k2')
    plt.subplot(2,2, 4)
    plt.imshow(output3)

    plt.title('Filtered Image-Edge Detection-k3')
    plt.show()

if __name__ == "__main__":
    main()

# %% [markdown]
# #  Box Blur

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

def main():
    img = cv.imread("test.jpg", 1)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

#k = np.array(np.ones((3.3). np.float32))/9 
#k = np.array(np.ohes ((77), np. Float32))/49
    k = np.array(np.ones((11, 11), np.float32))/121

#k= np.array(np.ones((15) 15), np.float32))/225

    print(k)
    output= cv.filter2D(img, -1, k)
    plt.subplot(1, 2, 1)
    plt.imshow(img)

    plt.title('Original Image')

    plt.subplot(1, 2, 2)
    plt.imshow(output)
    plt.title('Filtered Image-Box Blur')

    plt.show()

if __name__ == "__main__":
    main()
# Out:
# [[0.00826446 0.00826446 0.00826446 0.00826446 0.00826446 0.00826446
#   0.00826446 0.00826446 0.00826446 0.00826446 0.00826446]
#  [0.00826446 0.00826446 0.00826446 0.00826446 0.00826446 0.00826446
#   0.00826446 0.00826446 0.00826446 0.00826446 0.00826446]
#  [0.00826446 0.00826446 0.00826446 0.00826446 0.00826446 0.00826446
#   0.00826446 0.00826446 0.00826446 0.00826446 0.00826446]
#  [0.00826446 0.00826446 0.00826446 0.00826446 0.00826446 0.00826446
#   0.00826446 0.00826446 0.00826446 0.00826446 0.00826446]
#  [0.00826446 0.00826446 0.00826446 0.00826446 0.00826446 0.00826446
#   0.00826446 0.00826446 0.00826446 0.00826446 0.00826446]
#  [0.00826446 0.00826446 0.00826446 0.00826446 0.00826446 0.00826446
#   0.00826446 0.00826446 0.00826446 0.00826446 0.00826446]
#  [0.00826446 0.00826446 0.00826446 0.00826446 0.00826446 0.00826446
#   0.00826446 0.00826446 0.00826446 0.00826446 0.00826446]
#  [0.00826446 0.00826446 0.00826446 0.00826446 0.00826446 0.00826446
# ...

# %% [markdown]
# # Sharpen

# %%
import numpy as np 
import cv2 as cv

import matplotlib.pyplot as plt

def main():
    img=cv.imread("test.jpg", 1)
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
    k1= np.array(([0, -1, 0], [-1, 5, -1], [0, -1, 0]), np.float32)

    print(k1)
    print(type (k1))
    
    output= cv.filter2D(img, -1, k1)
    plt.subplot(1, 2, 1)
    plt.imshow(img)

    plt.title('Original Image')
    plt.subplot(1, 2, 2)
    plt.imshow(output)

    plt.title('Sharper Edges')
    plt.subplot(1, 2, 2)
    plt.imshow(output)

    plt.title('Sharpen Edges')
    plt.show()
if __name__=="__main__":
    main()
# Out:
# [[ 0. -1.  0.]
#  [-1.  5. -1.]
#  [ 0. -1.  0.]]
# <class 'numpy.ndarray'>

# %% [markdown]
# # Noise Add and Remove

# %%
import random
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

def main():
#Function defination
    img = cv.imread("test.jpg")
    img = cv.cvtColor(img, cv.COLOR_BGR2RGB) 
    plt.imshow(img)
    rows, cols, chan = img.shape
#rows, cols= img.shape
    p = 0.25
    output = np.zeros(img.shape, np.uint8)
    for i in range(rows):
        for j in range(cols):
            r=random.random()
            if r < p/2:
                output[i][j] = [0,0,0]
            elif r<p:
                output[i][j] = [255,255,255]
            else:
                output[i][j] = img[i][j]
    denoised = cv.medianBlur(output, 3)
    result = [img, output, denoised]
    titles= [ 'Original', 'Noisy', 'Denoised']

    for i in range(3):
        plt.subplot(1,3,i+1)
        plt.imshow(result[i])
        plt.title(titles[i])
        plt.xticks([])
        plt.yticks([])
    plt.show()

if __name__=="__main__":
    main()
# Out:
# C:\Users\rocks\AppData\Local\Temp\ipykernel_9260\3847486927.py:29: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(1,3,i+1)

# %% [markdown]
# # Display the sample Image- Monochrome Format

# %%
from skimage import data
from skimage import filters
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
cat = data.astronaut()
gray_cat = rgb2gray(cat)

plt.figure(figsize=(15,15))

for i in range(10):
    binarized_gray = (gray_cat >i*0.1)*1
    plt.subplot(5,2,i+1)
    
    plt.title("threshold: >"+str(round(i*0.1,1)))
    plt.imshow(binarized_gray,cmap ='gray')
plt.tight_layout()

# %% [markdown]
# # Image segmentation using threshold value

# %%
import cv2 as cv
from skimage import data
from skimage import filters
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

img = cv.imread(r"test.jpg")
#img = cv.cvtcolor(img,cv.COLOR_BGR2GRAY)
plt.imshow(img)

# %%
#binary Threshold
ret,thresh = cv.threshold(img,127,255,cv.THRESH_BINARY)
plt.imshow(thresh)

# %%
#Binary Inverse Threshold

ret,thresh = cv.threshold(img,127,255,cv.THRESH_BINARY_INV)

plt.imshow(thresh)

# %%
#THreshold Truncate
ret,thresh = cv.threshold(img,127,255,cv.THRESH_TRUNC)
plt.imshow(thresh)

# %%
#Zero Threshold 

ret,thresh = cv.threshold(img,127,255,cv.THRESH_TOZERO)
plt.imshow(thresh)
